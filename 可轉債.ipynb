# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
#可轉債實際價格
df = pd.read_csv("/content/drive/MyDrive/政大課程/111財務數學/可轉債/28886.csv", encoding="big5")
df.dropna(inplace=True)
df['month_day'] = df['日期'].astype(str).str.split('111', expand=True)[1]
df['year'] = '2022'
df['Date'] = df['year']+df['month_day']
df['Date'] = pd.to_datetime(df['Date'], format="%Y%m%d")
display(df)

#股票實際價格
stock = pd.read_csv("/content/drive/MyDrive/政大課程/111財務數學/可轉債/2888.TW.csv")
stock['Date'] = pd.to_datetime(stock['Date'])
stock = stock.loc[(stock['Date']>='2022-07-01')&(stock['Date']<='2022-07-31')]
display(stock)
# Out:
#          日期 交易模式     收市價    漲跌     開市價     最高價     最低價  成交筆數     單位  \
# 1   1110701   等價  107.80 -0.85  108.80  108.80  107.00  14.0   22.0
# 5   1110705   等價  107.30  0.25  107.70  107.70  107.00  16.0   50.0
# 7   1110706   等價  107.75  0.45  107.75  107.75  107.75   1.0    1.0
# 9   1110707   等價  107.70 -0.05  107.00  107.75  107.00   5.0    7.0
# 13  1110711   等價  107.60  0.00  107.60  107.60  107.60   2.0    3.0
# 15  1110712   等價  105.90 -1.70  106.50  106.50  105.00  13.0   55.0
# 17  1110713   等價  105.90  0.00  106.00  106.00  105.60  13.0   44.0
# 19  1110714   等價  105.90  0.00  105.90  105.90  105.90  11.0   26.0
# 21  1110715   等價  105.70 -0.20  106.00  106.00  105.00  12.0   65.0
# 23  1110718   等價  105.70  0.00  105.70  105.70  105.70   2.0    5.0
# 25  1110719   等價  105.85  0.15  105.85  105.85  105.85   1.0    3.0
# 27  1110720   等價  106.00  0.15  106.00  106.00  106.00   7.0   22.0
# 29  1110721   等價  105.85 -0.15  105.10  105.85  105.10   5.0   28.0
# 31  1110722   等價  105.50 -0.35  106.20  106.20  105.50   8.0  108.0
# 33  1110725   等價  105.75  0.25  105.75  105.75  105.75   1.0    5.0
# 35  1110726   等價  105.80  0.05  105.80  105.80  105.80   1.0    5.0
# 37  1110727   等價  105.85  0.05  105.65  105.85  105.60  27.0  291.0
# 39  1110728   等價  105.90  0.05  105.90  105.90  105.90   2.0    6.0
# 41  1110729   等價  105.50 -0.40  105.85  105.85  105.50   4.0    7.0
#
#        成交金額(元)     平均價 month_day  year       Date
# 1    2362400.0  107.38      0701  2022 2022-07-01
# 5    5369550.0  107.39      0705  2022 2022-07-05
# 7     107750.0  107.75      0706  2022 2022-07-06
# 9     750450.0  107.20      0707  2022 2022-07-07
# 13    322800.0  107.60      0711  2022 2022-07-11
# 15   5800200.0  105.45      0712  2022 2022-07-12
# 17   4656600.0  105.83      0713  2022 2022-07-13
# 19   2753400.0  105.90      0714  2022 2022-07-14
# 21   6838050.0  105.20      0715  2022 2022-07-15
# 23    528500.0  105.70      0718  2022 2022-07-18
# 25    317550.0  105.85      0719  2022 2022-07-19
# 27   2332000.0  106.00      0720  2022 2022-07-20
# 29   2944250.0  105.15      0721  2022 2022-07-21
# 31  11424600.0  105.78      0722  2022 2022-07-22
# 33    528750.0  105.75      0725  2022 2022-07-25
# 35    529000.0  105.80      0726  2022 2022-07-26
# 37  30735450.0  105.62      0727  2022 2022-07-27
# 39    635400.0  105.90      0728  2022 2022-07-28
# 41    740600.0  105.80      0729  2022 2022-07-29
#            Date  Open  High   Low  Close  Adj Close    Volume
# 1218 2022-07-01  8.75  8.78  8.48   8.50       8.50  72998485
# 1219 2022-07-04  8.52  8.57  8.29   8.33       8.33  61724926
# 1220 2022-07-05  8.43  8.62  8.42   8.52       8.52  43435416
# 1221 2022-07-06  8.53  8.55  8.37   8.43       8.43  32820829
# 1222 2022-07-07  8.46  8.56  8.35   8.51       8.51  35036188
# 1223 2022-07-08  8.53  8.59  8.47   8.51       8.51  30649760
# 1224 2022-07-11  8.53  8.53  8.41   8.45       8.45  19868795
# 1225 2022-07-12  8.40  8.40  8.17   8.20       8.20  55398503
# 1226 2022-07-13  8.31  8.47  8.30   8.43       8.43  40874501
# 1227 2022-07-14  8.39  8.49  8.36   8.49       8.49  19927531
# 1228 2022-07-15  8.45  8.46  8.32   8.33       8.33  30061065
# 1229 2022-07-18  8.38  8.47  8.34   8.47       8.47  28493175
# 1230 2022-07-19  8.45  8.52  8.41   8.52       8.52  16597531
# 1231 2022-07-20  8.58  8.63  8.43   8.46       8.46  46515016
# 1232 2022-07-21  8.44  8.46  8.30   8.46       8.46  41404219
# 1233 2022-07-22  8.45  8.54  8.41   8.47       8.47  26968594
# 1234 2022-07-25  8.47  8.52  8.41   8.49       8.49  17073599
# 1235 2022-07-26  8.49  8.58  8.47   8.52       8.52  20188425
# 1236 2022-07-27  8.53  8.55  8.38   8.42       8.42  43740049
# 1237 2022-07-28  8.49  8.54  8.45   8.51       8.51  26310386
# 1238 2022-07-29  8.55  8.56  8.49   8.55       8.55  29213971

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:orange'
ax1.set_xlabel('Date')
ax1.set_ylabel('28886 Close price', color=color)
ax1.plot(df['Date'], df['收市價'], color=color)
plt.xticks(rotation=45)
plt.grid(axis='x')

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('2888.TW Close price', color=color)
ax2.plot(stock['Date'], stock['Close'], color=color)

fig.tight_layout()
# plt.savefig("/content/drive/MyDrive/政大課程/111財務數學/可轉債/price.png", bbox_inches='tight')
               
plt.show()

# %%
data = pd.merge(df[['Date', "收市價"]], stock[['Date', 'Close']], on='Date', how='left')
data.rename(columns={"收市價":"Market price", "Close":"Stock price"}, inplace=True)
data
# Out:
#          Date  Market price  Stock price
# 0  2022-07-01        107.80         8.50
# 1  2022-07-05        107.30         8.52
# 2  2022-07-06        107.75         8.43
# 3  2022-07-07        107.70         8.51
# 4  2022-07-11        107.60         8.45
# 5  2022-07-12        105.90         8.20
# 6  2022-07-13        105.90         8.43
# 7  2022-07-14        105.90         8.49
# 8  2022-07-15        105.70         8.33
# 9  2022-07-18        105.70         8.47
# 10 2022-07-19        105.85         8.52
# 11 2022-07-20        106.00         8.46
# 12 2022-07-21        105.85         8.46
# 13 2022-07-22        105.50         8.47
# 14 2022-07-25        105.75         8.49
# 15 2022-07-26        105.80         8.52
# 16 2022-07-27        105.85         8.42
# 17 2022-07-28        105.90         8.51
# 18 2022-07-29        105.50         8.55

# %%
rate = pd.read_csv("/content/drive/MyDrive/政大課程/111財務數學/可轉債/2888.TW.csv")
rate['Date'] = pd.to_datetime(rate['Date'])
rate = rate.loc[(rate['Date']>='2017-07-01')&(rate['Date']<'2022-07-01')]
rate = rate['Close'].pct_change().std() * 365**0.5
rate#股票歷史波動度
# Out:
# 0.30681187301814894

# %% [markdown]
# $CB_t=e^{-r(T-t)}F+qS_tN(d_1)-Fe^{-r(T-t)}N(d_2)$
#
# $d_1=\frac{\ln(\frac{qS_t}{F})+(r+\frac{1}{2}\sigma^2)(T-t)}{\sigma\sqrt{T-t}}$
#
# $d_2=\frac{\ln(\frac{qS_t}{F})+(r-\frac{1}{2}\sigma^2)(T-t)}{\sigma\sqrt{T-t}}=d_1-\sigma\sqrt{T-t}$
#
# 其中$CB_t$為可轉債在$t$時間點的價格；$r$為無風險利率；$T$為到期日時機點；$t$為目前時間點；$F$為債券面額；$q$為轉換比率；$\sigma$為股票報酬波動度；$S_t$為股票在$t$的價格。

# %%
def bond_price(S, F, q, r, sigma, T):
  d1 = (math.log(q*S/F)+(r+0.5*sigma**2)*T)/(sigma*math.sqrt(T))
  d2 = d1-sigma*math.sqrt(T)
  price = math.exp(-r*T)*F + q*S*norm.cdf(d1) - F*math.exp(-r*T)*norm.cdf(d2)
  return price

import math
from scipy.stats import norm
from datetime import datetime

maturity = datetime.strptime("2023-12-17", "%Y-%m-%d") #到期日
data['T'] = (maturity - data['Date']).dt.days/ 365 #距到期日

F = 100 #面額，通常為100
q = 0.0001 #轉換比率
r = 0.0108 #無風險利率
sigma = 0.3068 #股價波動度

thm = list(map(lambda S, T: bond_price(S, F, q, r, sigma, T), data['Stock price'], data['T']))
data['Theoretical price'] = thm
data['Error rate'] = round((abs(data['Theoretical price'] - data['Market price'])/ data['Market price'])*100, 2)
data.to_csv("/content/drive/MyDrive/政大課程/111財務數學/可轉債/result.csv")

# %%
import matplotlib as mpl

fig, ax1 = plt.subplots(figsize=(10,5))
# label_size = 8
mpl.rcParams['xtick.labelsize'] = 14 
mpl.rcParams['ytick.labelsize'] = 14 

ax1.set_xlabel('Date', fontsize='16')
ax1.set_ylabel('Price', fontsize='16')
f1 = ax1.plot(data['Date'], data['Market price'], marker='^', label='Market price',ms=10)
f2 = ax1.plot(data['Date'], data['Theoretical price'], marker='o', label='Theoretical price',ms=10)

plt.xticks(rotation=45)
plt.grid(axis='x')

ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Error rate(%)', color=color, fontsize='16')

f3 = ax2.plot(data['Date'], data['Error rate'], color=color, marker='s',ms=10,label='Error rate(%)')
fig.tight_layout()


# added these three lines
lns = f1+f2+f3
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, fontsize=12, loc='center left', bbox_to_anchor=(1.11, 0.5),shadow=True, ncol=1)


plt.savefig("/content/drive/MyDrive/政大課程/111財務數學/可轉債/error.png", bbox_inches='tight')
               
plt.show()
